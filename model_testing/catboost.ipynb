# %%
import os 
import matplotlib
import opendatasets as od
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import math
import re
import datetime

from catboost import CatBoostRegressor
from sklearn.metrics import root_mean_squared_error as rmse
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from xgboost import XGBRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score

currentDateTime = datetime.datetime.now()
date = currentDateTime.date()
year = int(date.strftime("%Y"))

matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10, 6)
matplotlib.rcParams['figure.facecolor'] = "#949494"

# %matplotlib inline

# %%
od.download('https://www.kaggle.com/c/playground-series-s4e9')
os.listdir('playground-series-s4e9')
train = pd.read_csv('playground-series-s4e9/train.csv', low_memory=False)
test = pd.read_csv('playground-series-s4e9/test.csv', low_memory=False)
sub = pd.read_csv('playground-series-s4e9/sample_submission.csv')
train = train.copy()
# Out:
# Skipping, found downloaded files in "./playground-series-s4e9" (use force=True to force download)

# %%
def convert_engine(val):
    d = {
        'engine_HP': np.nan,
        'engine_L': np.nan,
        'engine_cylinder': np.nan,
        'engine_cylinder_type': np.nan,
        'engine_fuel_type': np.nan,
        'engine_type': np.nan,
        'engine_v': np.nan,
        'engine_vtype': np.nan
    }
    spl = val.replace('-', '').split(' ')
    pos_v1 = -1
    pos_v2 = -1
    for i, v in enumerate(spl):
        if v.endswith('HP'):
            d['engine_HP'] = float(v[:-2])
        elif v.endswith('L'):
            d['engine_L'] = float(v[:-1])
        elif v == 'Engine' and spl[i-1] == 'Cylinder':
            d['engine_cylinder'] = abs(float(spl[i-2].replace('V', '')))
        elif v == 'Fuel':
            d['engine_fuel_type'] = spl[i - 1]
        elif v == 'Liter':
            d['engine_L'] = float(spl[i-1])
        elif v.startswith('V') or v.startswith('H') or v.startswith('I'):
            try:
                d['engine_cylinder'] = float(v[1:])
                d['engine_cylinder_type'] = v[0]
                pos_v1 = i
            except:
                pass
        elif v == 'DOHC' or v == 'OHV':
            d['engine_type'] = ' '.join(spl[i:])
            if pos_v2 != -1:
                d['engine_vtype'] = ' '.join(spl[pos_v2+1:i])
            elif pos_v1 != -1:
                d['engine_vtype'] = ' '.join(spl[pos_v1+1:i])
        elif v.endswith('V'):
            try:
                d['engine_v'] = float(v[:-1])
                pos_v2 = i
            except:
                pass
    return d

def test_params(ModelClass, **params):
    model = ModelClass(**params).fit(X_train, Y_train)
    train_rmse = rmse(model.predict(X_train), Y_train)
    val_rmse = rmse(model.predict(X_val), Y_val)
    return train_rmse, val_rmse


def test_param_and_plot(ModelClass, param_name, param_values, **other_params):
    train_errors, val_errors = [], [] 
    for value in param_values:
        params = dict(other_params)
        params[param_name] = value
        train_rmse, val_rmse = test_params(ModelClass, **params)
        train_errors.append(train_rmse)
        val_errors.append(val_rmse)
    
    plt.figure(figsize=(10,6))
    plt.title('Overfitting curve: ' + param_name)
    plt.plot(param_values, train_errors, 'b-o')
    plt.plot(param_values, val_errors, 'r-o')
    for x,y in zip(param_values,val_errors):
        label = "{:.2f}".format(y)
        plt.annotate(label,
                    (x,y),
                    textcoords="offset points",
                    xytext=(0,10),
                    ha='center')

    plt.xlabel(param_name)
    plt.ylabel('RMSE')
    plt.legend(['Training', 'Validation'])
    plt.show()

# %%
average_prices_by_brand = train.groupby('brand')['price'].mean()

train = train.fillna('dash')
train = train.replace('–', 'dash')

test = test.fillna('dash')
test = test.replace('–', 'dash')

accident_dict = {
    'None reported': 0,
    'At least 1 accident or damage reported': 1,
    'uknown': 2
}

clean_title_dict = {
    'Yes': 0,
    'uknown': 1
}

expensive_ext_color = ['Blue Caelum', 'Dark Sapphire', 'Bianco Monocerus', 'C / C', 'Ice',
       'Tempest', 'Beluga Black', 'Bianco Icarus Metallic', 
       'BLU ELEOS', 'Shadow Black', 'Nero Noctis', 'Sandstone Metallic',
       'Lizard Green', 'Balloon White', 'Onyx', 'Donington Grey Metallic',
       'China Blue', 'Diamond White', 'Rosso Corsa', 'Granite',
       'Rosso Mars Metallic', 'Carpathian Grey', 'Kemora Gray Metallic',
       'Grigio Nimbus', 'dash', 'Bianco Isis', 'Python Green', 'Fountain Blue',
       'Custom Color', 'Vega Blue', 'Designo Magno Matte',
       'Brands Hatch Gray Metallic', 'Rift Metallic', 'Gentian Blue Metallic',
       'Arancio Borealis', 'BLUE', 'Aventurine Green Metallic', 'Apex Blue',
       'Daytona Gray Pearl Effect', 'Daytona Gray Pearl Effect w/ Black Roof',
       'Matte White', 'Carpathian Grey Premium Metallic', 'Blue Metallic',
       'Santorini Black Metallic', 'Quartzite Grey Metallic',
       'Carrara White Metallic', 'BLACK', 'Kinetic Blue', 'Nero Daytona']

expensive_int_color = ['Dark Auburn', 'Hotspur', 'Cobalt Blue', 'Beluga Hide', 'Linen',
                       'Beluga', 'Black / Brown', 'Nero Ade', 'Sahara Tan', 'Portland']

inexpensive_ext_color = ['Gold', 'Frozen White', 'Beige', 'Volcanic Orange',
        'Mountain Air Metallic', 'Crystal Black Pearl', 'Crimson Red Tintcoat',
        'Snowflake White Pearl', 'Sonic Silver Metallic', 'Radiant Red Metallic II',
        'Remington Red Metallic', 'Gecko Pearlcoat', 'Dazzling White',
        'Blue Reflex Mica', 'White Platinum Tri-Coat Metallic', 'Purple',
        'Crystal White Pearl', 'Silver', 'Jet Black Mica', 'Red Quartz Tintcoat']

inexpensive_int_color =['Light Gray', 'Gray', 'Medium Pewter', 'Beige', 'Medium Ash Gray',
       'White / Brown', 'Ash', 'Deep Chestnut', 'Charcoal Black',
       'Whisper Beige', 'Gideon', 'Light Platinum / Jet Black', 'Sand Beige',
       'Mountain Brown', 'Ivory / Ebony', 'Black / Graphite', 'Canberra Beige',
       'Tupelo', 'Charcoal', 'Gold']

low_end_brand = average_prices_by_brand[average_prices_by_brand < 25000].index.tolist()
mid_range_brand = average_prices_by_brand[(average_prices_by_brand > 25000) & (average_prices_by_brand < 40000)].index.tolist()
high_end_brand = average_prices_by_brand[(average_prices_by_brand > 40000) & (average_prices_by_brand < 80000)].index.tolist()
luxury_brand = average_prices_by_brand[average_prices_by_brand > 80000].index.tolist()

def encode_columns(df):
    gases = df.fuel_type.value_counts().index
    for gas in gases:
        df.loc[(df['fuel_type'] == '–') & df['engine'].str.contains(gas), 'fuel_type'] = gas

    milage_per_year = df['milage'] / (year - df['model_year'])

    auto_transmission = df['transmission'].str.contains('A/T') + df['transmission'].str.contains(' At') + df['transmission'].str.contains('Automatic') + df['transmission'].str.contains('Dual Shift') + df['transmission'].str.contains('CVT Transmission') + df['transmission'].str.contains('CVT-F') + df['transmission'].str.contains('Overdrive Switch') + df['transmission'].str.contains('Variable')
    manual_transmission = df['transmission'].str.contains('M/T') + df['transmission'].str.contains(' Mt') + df['transmission'].str.contains('Manual')
    
    df['milage_per_year'] = milage_per_year.astype(int)
    
    df['auto_transmission'] = auto_transmission.astype(int)
    df['manual_transmission'] = manual_transmission.astype(int)

    df['turbo_engine'] = df['engine'].str.contains('Turbo').astype(int)
    df['supercharged_engine'] = df['engine'].str.contains('Supercharged').astype(int)
    df['dohc_engine'] = df['engine'].str.contains('DOHC').astype(int)
    df['ohv_engine'] = df['engine'].str.contains('OHV').astype(int)


    df['low_end_brand'] = df.brand.isin(low_end_brand).astype(int)
    df['mid_range_brand'] = df.brand.isin(mid_range_brand).astype(int)
    df['high_end_brand'] = df.brand.isin(high_end_brand).astype(int)
    df['luxury_brand'] = df.brand.isin(luxury_brand).astype(int)

    df['accident_encoded'] = df['accident'].map(accident_dict)
    df['clean_title_encoded'] = df['clean_title'].map(clean_title_dict)

    df['expensive_color_ext_encoded'] = df.ext_col.isin(expensive_ext_color).astype(int)
    df['expensive_color_int_encoded'] = df.int_col.isin(expensive_int_color).astype(int)
    df['inexpensive_color_ext_encoded'] = df.ext_col.isin(inexpensive_ext_color).astype(int)
    df['inexpensive_color_int_encoded'] = df.int_col.isin(inexpensive_int_color).astype(int)

    df['engine_fuel_type'].replace('dash', np.nan)
    df['engine_fuel_type'] = df.engine_fuel_type.fillna(df['fuel_type'])
    df['engine_fuel_type'] = df.engine_fuel_type.replace('Flexible', 'Flex').replace('E85 Flex Fuel', 'Flex')

    df['engine_HP_per_L'] = df['engine_HP']/df['engine_L']
    
    return df

train = pd.concat([train, pd.DataFrame.from_records(train['engine'].map(convert_engine).values)], axis = 1)
test = pd.concat([test, pd.DataFrame.from_records(test['engine'].map(convert_engine).values)], axis = 1)


train = encode_columns(train)
test = encode_columns(test)

# %%
input_cols = ['model_year', 'milage', 'milage_per_year', 'engine_fuel_type', 
       'low_end_brand', 'mid_range_brand', 'high_end_brand', 'luxury_brand', 
       'turbo_engine', 'dohc_engine', 'supercharged_engine', 'ohv_engine',
       'accident_encoded', 'clean_title_encoded', 'inexpensive_color_int_encoded',
       'expensive_color_ext_encoded', 'expensive_color_int_encoded', 'inexpensive_color_ext_encoded',
       'auto_transmission', 'manual_transmission', 'engine_HP', 'engine_L', 'engine_HP_per_L',
       'engine_cylinder', 'engine_cylinder_type', 'engine_v', 'engine_vtype']

target_col = 'price'

train_df, val_df = train_test_split(train, test_size=0.25, random_state=42)

X_train = train_df[input_cols].copy()
Y_train = train_df[target_col].copy()

X_val = val_df[input_cols].copy()
Y_val = val_df[target_col].copy()

test_inputs = test[input_cols].copy()

numeric_cols = X_train.select_dtypes(include=np.number).columns.tolist()
categorical_cols = X_train.select_dtypes('object').columns.tolist()

# %%
imputer = SimpleImputer(strategy='mean').fit(X_train[numeric_cols])

X_train[numeric_cols] = imputer.transform(X_train[numeric_cols])
X_val[numeric_cols] = imputer.transform(X_val[numeric_cols])
test_inputs[numeric_cols] = imputer.transform(test_inputs[numeric_cols])

scaler = MinMaxScaler().fit(X_train[numeric_cols])

X_train[numeric_cols] = scaler.transform(X_train[numeric_cols])
X_val[numeric_cols] = scaler.transform(X_val[numeric_cols])
test_inputs[numeric_cols] = scaler.transform(test_inputs[numeric_cols])

encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore').fit(X_train[categorical_cols])
encoded_cols = list(encoder.get_feature_names_out(categorical_cols))

X_train[encoded_cols] = encoder.transform(X_train[categorical_cols])
X_val[encoded_cols] = encoder.transform(X_val[categorical_cols])
test_inputs[encoded_cols] = encoder.transform(test_inputs[categorical_cols])

train_df = X_train[numeric_cols + encoded_cols]
val_df = X_val[numeric_cols + encoded_cols]
test = test_inputs[numeric_cols + encoded_cols]

numeric_cols_df = train_df.select_dtypes(include=np.number).columns.tolist()
categorical_cols_df = train_df.select_dtypes('object').columns.tolist()

# %%
X_train, Y_train = train_df, Y_train
X_val, Y_val = val_df, Y_val

model = CatBoostRegressor(task_type="GPU",
                           devices='0')
model.fit(X_train, Y_train)

train_preds = model.predict(X_train)
val_preds = model.predict(X_val)

print(rmse(Y_train, train_preds))
print(rmse(Y_val, val_preds))
# Out:
# Learning rate set to 0.077272
# 0:	learn: 80315.1394512	total: 3.15ms	remaining: 3.15s
# 1:	learn: 79719.3521471	total: 4.99ms	remaining: 2.49s
# 2:	learn: 79197.0403571	total: 7.5ms	remaining: 2.49s
# 3:	learn: 78736.2071526	total: 9.38ms	remaining: 2.34s
# 4:	learn: 78335.1475435	total: 11.9ms	remaining: 2.36s
# 5:	learn: 77956.8094196	total: 13.7ms	remaining: 2.28s
# 6:	learn: 77636.0082985	total: 15.6ms	remaining: 2.21s
# 7:	learn: 77348.0886668	total: 18.1ms	remaining: 2.25s
# 8:	learn: 77100.5567729	total: 20.6ms	remaining: 2.27s
# 9:	learn: 76859.6657271	total: 22.5ms	remaining: 2.23s
# 10:	learn: 76676.7986612	total: 24.5ms	remaining: 2.2s
# 11:	learn: 76495.0827742	total: 27.2ms	remaining: 2.24s
# 12:	learn: 76366.5933457	total: 29.1ms	remaining: 2.21s
# 13:	learn: 76233.6540197	total: 31.6ms	remaining: 2.23s
# 14:	learn: 76117.7184043	total: 33.5ms	remaining: 2.2s
# 15:	learn: 75998.3773642	total: 35.3ms	remaining: 2.17s
# 16:	learn: 75893.7742180	total: 38ms	remaining: 2.19s
# 17:	learn: 75790.5452691	total: 40.6ms	remaining: 2.21s
# 18:	learn: 75694.3425194	total: 42.4ms	remaining: 2.19s
# 19:	learn: 75615.8730840	total: 44.3ms	remaining: 2.17s
# 20:	learn: 75548.8192782	total: 47ms	remaining: 2.19s
# 21:	learn: 75478.9172589	total: 49.7ms	remaining: 2.21s
# 22:	learn: 75402.0175394	total: 51.7ms	remaining: 2.19s
# 23:	learn: 75340.8589051	total: 53.6ms	remaining: 2.18s
# 24:	learn: 75277.7907112	total: 56.2ms	remaining: 2.19s
# 25:	learn: 75232.2252265	total: 58.1ms	remaining: 2.17s
# 26:	learn: 75182.6994141	total: 60.6ms	remaining: 2.18s
# 27:	learn: 75143.7399173	total: 62.5ms	remaining: 2.17s
# 28:	learn: 75110.0713595	total: 64.4ms	remaining: 2.16s
# 29:	learn: 75069.3102863	total: 67ms	remaining: 2.17s
# 30:	learn: 75038.3407173	total: 69.4ms	remaining: 2.17s
# 31:	learn: 75010.0538126	total: 71.3ms	remaining: 2.16s
# 32:	learn: 74973.8089721	total: 73.4ms	remaining: 2.15s
# 33:	learn: 74923.9603153	total: 76.1ms	remaining: 2.16s
# 34:	learn: 74896.9007493	total: 78ms	remaining: 2.15s
# 35:	learn: 74866.8297856	total: 81ms	remaining: 2.17s
# 36:	learn: 74833.3474089	total: 83.3ms	remaining: 2.17s
# 37:	learn: 74802.7337996	total: 86.2ms	remaining: 2.18s
# 38:	learn: 74774.5545279	total: 88.9ms	remaining: 2.19s
# 39:	learn: 74750.1869687	total: 91ms	remaining: 2.18s
# 40:	learn: 74728.7266552	total: 93.1ms	remaining: 2.18s
# 41:	learn: 74707.4475868	total: 95.8ms	remaining: 2.19s
# 42:	learn: 74691.1570639	total: 97.9ms	remaining: 2.18s
# 43:	learn: 74671.5834062	total: 101ms	remaining: 2.19s
# 44:	learn: 74650.9651442	total: 103ms	remaining: 2.18s
# 45:	learn: 74638.1183624	total: 106ms	remaining: 2.19s
# 46:	learn: 74604.8609638	total: 108ms	remaining: 2.18s
# 47:	learn: 74581.9111392	total: 110ms	remaining: 2.19s
# 48:	learn: 74563.7568791	total: 113ms	remaining: 2.18s
# 49:	learn: 74548.7719094	total: 115ms	remaining: 2.19s
# 50:	learn: 74531.9181771	total: 117ms	remaining: 2.18s
# 51:	learn: 74516.8185299	total: 120ms	remaining: 2.19s
# 52:	learn: 74501.5087839	total: 122ms	remaining: 2.18s
# 53:	learn: 74487.0242121	total: 125ms	remaining: 2.19s
# 54:	learn: 74473.9707129	total: 127ms	remaining: 2.18s
# 55:	learn: 74452.7527002	total: 130ms	remaining: 2.19s
# 56:	learn: 74429.9919069	total: 132ms	remaining: 2.18s
# 57:	learn: 74403.5053937	total: 134ms	remaining: 2.18s
# 58:	learn: 74380.2892561	total: 137ms	remaining: 2.18s
# 59:	learn: 74371.9012108	total: 140ms	remaining: 2.19s
# 60:	learn: 74356.6063067	total: 142ms	remaining: 2.18s
# 61:	learn: 74329.6179508	total: 145ms	remaining: 2.19s
# 62:	learn: 74318.5229107	total: 147ms	remaining: 2.19s
# 63:	learn: 74299.2918416	total: 150ms	remaining: 2.19s
# 64:	learn: 74283.4612755	total: 152ms	remaining: 2.18s
# 65:	learn: 74264.3585287	total: 155ms	remaining: 2.19s
# 66:	learn: 74252.7967277	total: 157ms	remaining: 2.18s
# 67:	learn: 74226.2629702	total: 160ms	remaining: 2.19s
# 68:	learn: 74208.4278251	total: 162ms	remaining: 2.18s
# 69:	learn: 74191.6183223	total: 164ms	remaining: 2.18s
# 70:	learn: 74178.0041834	total: 167ms	remaining: 2.18s
# 71:	learn: 74159.9494402	total: 169ms	remaining: 2.18s
# 72:	learn: 74150.8996182	total: 171ms	remaining: 2.17s
# 73:	learn: 74131.5834503	total: 173ms	remaining: 2.17s
# 74:	learn: 74103.6677367	total: 176ms	remaining: 2.17s
# 75:	learn: 74076.9364066	total: 179ms	remaining: 2.17s
# 76:	learn: 74060.9013082	total: 181ms	remaining: 2.17s
# 77:	learn: 74046.0228863	total: 184ms	remaining: 2.17s
# 78:	learn: 74028.5482191	total: 186ms	remaining: 2.17s
# 79:	learn: 74015.5260767	total: 189ms	remaining: 2.17s
# 80:	learn: 74001.9212295	total: 191ms	remaining: 2.17s
# 81:	learn: 73996.1906053	total: 194ms	remaining: 2.17s
# 82:	learn: 73984.1570950	total: 197ms	remaining: 2.17s
# 83:	learn: 73963.6680422	total: 199ms	remaining: 2.17s
# 84:	learn: 73951.6099864	total: 201ms	remaining: 2.16s
# 85:	learn: 73943.3819140	total: 204ms	remaining: 2.16s
# 86:	learn: 73939.6430373	total: 207ms	remaining: 2.17s
# 87:	learn: 73919.2957407	total: 209ms	remaining: 2.16s
# 88:	learn: 73885.6890926	total: 211ms	remaining: 2.16s
# 89:	learn: 73864.9317770	total: 213ms	remaining: 2.16s
# 90:	learn: 73850.2002454	total: 216ms	remaining: 2.15s
# 91:	learn: 73843.8633371	total: 218ms	remaining: 2.15s
# 92:	learn: 73835.4914861	total: 220ms	remaining: 2.15s
# 93:	learn: 73822.3774276	total: 223ms	remaining: 2.15s
# 94:	learn: 73808.1325350	total: 225ms	remaining: 2.14s
# 95:	learn: 73801.3900870	total: 228ms	remaining: 2.14s
# 96:	learn: 73791.1160742	total: 230ms	remaining: 2.14s
# 97:	learn: 73780.9435530	total: 232ms	remaining: 2.13s
# 98:	learn: 73768.2508597	total: 235ms	remaining: 2.13s
# 99:	learn: 73763.9304712	total: 237ms	remaining: 2.13s
# 100:	learn: 73746.4983666	total: 239ms	remaining: 2.13s
# 101:	learn: 73731.8493814	total: 241ms	remaining: 2.13s
# 102:	learn: 73717.6932252	total: 244ms	remaining: 2.13s
# 103:	learn: 73699.3969211	total: 247ms	remaining: 2.12s
# 104:	learn: 73685.4792878	total: 249ms	remaining: 2.12s
# 105:	learn: 73669.9613442	total: 251ms	remaining: 2.12s
# 106:	learn: 73660.7740057	total: 254ms	remaining: 2.12s
# 107:	learn: 73648.0090481	total: 256ms	remaining: 2.12s
# 108:	learn: 73636.4793781	total: 258ms	remaining: 2.11s
# 109:	learn: 73629.4859375	total: 260ms	remaining: 2.1s
# 110:	learn: 73616.0708526	total: 263ms	remaining: 2.1s
# 111:	learn: 73608.2920780	total: 266ms	remaining: 2.1s
# 112:	learn: 73589.8041157	total: 268ms	remaining: 2.1s
# 113:	learn: 73576.9720164	total: 270ms	remaining: 2.1s
# 114:	learn: 73549.0845570	total: 272ms	remaining: 2.1s
# 115:	learn: 73538.0298743	total: 274ms	remaining: 2.09s
# 116:	learn: 73530.2783439	total: 277ms	remaining: 2.09s
# 117:	learn: 73510.2761371	total: 279ms	remaining: 2.08s
# 118:	learn: 73496.5551624	total: 281ms	remaining: 2.08s
# 119:	learn: 73489.6420493	total: 284ms	remaining: 2.08s
# 120:	learn: 73475.5458081	total: 286ms	remaining: 2.08s
# 121:	learn: 73452.4466696	total: 288ms	remaining: 2.08s
# 122:	learn: 73439.9363149	total: 290ms	remaining: 2.07s
# 123:	learn: 73433.1212815	total: 293ms	remaining: 2.07s
# 124:	learn: 73424.5668568	total: 296ms	remaining: 2.07s
# 125:	learn: 73413.0699761	total: 298ms	remaining: 2.07s
# 126:	learn: 73407.7330274	total: 300ms	remaining: 2.06s
# 127:	learn: 73397.7207571	total: 303ms	remaining: 2.06s
# 128:	learn: 73374.9787451	total: 305ms	remaining: 2.06s
# 129:	learn: 73359.0489956	total: 307ms	remaining: 2.06s
# 130:	learn: 73351.4694253	total: 309ms	remaining: 2.05s
# 131:	learn: 73335.1009633	total: 312ms	remaining: 2.05s
# 132:	learn: 73312.9383464	total: 315ms	remaining: 2.05s
# 133:	learn: 73300.7343962	total: 317ms	remaining: 2.05s
# 134:	learn: 73291.0377672	total: 319ms	remaining: 2.04s
# 135:	learn: 73272.4276537	total: 322ms	remaining: 2.05s
# 136:	learn: 73250.0031022	total: 325ms	remaining: 2.04s
# 137:	learn: 73232.3773744	total: 327ms	remaining: 2.04s
# 138:	learn: 73228.8873660	total: 329ms	remaining: 2.04s
# 139:	learn: 73215.3956392	total: 332ms	remaining: 2.04s
# 140:	learn: 73208.4657004	total: 334ms	remaining: 2.04s
# 141:	learn: 73199.1880203	total: 336ms	remaining: 2.03s
# 142:	learn: 73192.6877569	total: 338ms	remaining: 2.03s
# 143:	learn: 73164.1283889	total: 341ms	remaining: 2.03s
# 144:	learn: 73141.9691210	total: 343ms	remaining: 2.02s
# 145:	learn: 73126.4461744	total: 346ms	remaining: 2.02s
# 146:	learn: 73111.4814526	total: 348ms	remaining: 2.02s
# 147:	learn: 73092.0529275	total: 350ms	remaining: 2.02s
# 148:	learn: 73077.1168830	total: 353ms	remaining: 2.01s
# 149:	learn: 73063.1846463	total: 355ms	remaining: 2.01s
# 150:	learn: 73058.7446086	total: 357ms	remaining: 2.01s
# 151:	learn: 73056.6105661	total: 360ms	remaining: 2s
# 152:	learn: 73051.1533703	total: 363ms	remaining: 2.01s
# 153:	learn: 73034.4966570	total: 365ms	remaining: 2.01s
# 154:	learn: 73025.0538916	total: 367ms	remaining: 2s
# 155:	learn: 73014.3651316	total: 369ms	remaining: 2s
# 156:	learn: 73006.3044662	total: 372ms	remaining: 2s
# 157:	learn: 72996.3021533	total: 375ms	remaining: 2s
# 158:	learn: 72977.9680645	total: 377ms	remaining: 1.99s
# 159:	learn: 72965.3568440	total: 379ms	remaining: 1.99s
# 160:	learn: 72949.2693339	total: 381ms	remaining: 1.99s
# 161:	learn: 72942.5190692	total: 384ms	remaining: 1.99s
# 162:	learn: 72932.1403353	total: 386ms	remaining: 1.98s
# 163:	learn: 72919.9442489	total: 388ms	remaining: 1.98s
# 164:	learn: 72913.4256001	total: 391ms	remaining: 1.98s
# 165:	learn: 72893.8401122	total: 394ms	remaining: 1.98s
# 166:	learn: 72872.8914550	total: 396ms	remaining: 1.97s
# 167:	learn: 72848.2786947	total: 398ms	remaining: 1.97s
# 168:	learn: 72833.4425346	total: 401ms	remaining: 1.97s
# 169:	learn: 72820.1643128	total: 403ms	remaining: 1.97s
# 170:	learn: 72805.8928200	total: 405ms	remaining: 1.97s
# 171:	learn: 72791.4848676	total: 408ms	remaining: 1.96s
# 172:	learn: 72778.8902422	total: 411ms	remaining: 1.96s
# 173:	learn: 72760.2274097	total: 413ms	remaining: 1.96s
# 174:	learn: 72754.7610295	total: 416ms	remaining: 1.96s
# 175:	learn: 72738.0038193	total: 418ms	remaining: 1.96s
# 176:	learn: 72725.6772867	total: 421ms	remaining: 1.96s
# 177:	learn: 72719.9831457	total: 423ms	remaining: 1.95s
# 178:	learn: 72712.7449064	total: 425ms	remaining: 1.95s
# 179:	learn: 72704.0534984	total: 427ms	remaining: 1.95s
# 180:	learn: 72691.8224086	total: 430ms	remaining: 1.95s
# 181:	learn: 72676.2098454	total: 433ms	remaining: 1.94s
# 182:	learn: 72654.7607728	total: 435ms	remaining: 1.94s
# 183:	learn: 72641.1460790	total: 437ms	remaining: 1.94s
# 184:	learn: 72633.8869147	total: 440ms	remaining: 1.94s
# 185:	learn: 72623.4248627	total: 442ms	remaining: 1.93s
# 186:	learn: 72601.7052483	total: 444ms	remaining: 1.93s
# 187:	learn: 72591.8465958	total: 446ms	remaining: 1.93s
# 188:	learn: 72573.2795366	total: 448ms	remaining: 1.92s
# 189:	learn: 72565.1110109	total: 451ms	remaining: 1.92s
# 190:	learn: 72550.9136389	total: 454ms	remaining: 1.92s
# 191:	learn: 72546.2198169	total: 456ms	remaining: 1.92s
# 192:	learn: 72529.4340562	total: 458ms	remaining: 1.91s
# 193:	learn: 72513.8617981	total: 461ms	remaining: 1.91s
# 194:	learn: 72503.6606308	total: 463ms	remaining: 1.91s
# 195:	learn: 72477.0496764	total: 465ms	remaining: 1.91s
# 196:	learn: 72468.7753418	total: 467ms	remaining: 1.91s
# 197:	learn: 72459.2555776	total: 470ms	remaining: 1.91s
# 198:	learn: 72449.3971937	total: 473ms	remaining: 1.9s
# 199:	learn: 72440.3564334	total: 475ms	remaining: 1.9s
# 200:	learn: 72431.3047158	total: 477ms	remaining: 1.9s
# 201:	learn: 72411.0448188	total: 480ms	remaining: 1.9s
# 202:	learn: 72397.0630691	total: 483ms	remaining: 1.89s
# 203:	learn: 72383.3015519	total: 485ms	remaining: 1.89s
# 204:	learn: 72370.4817775	total: 487ms	remaining: 1.89s
# 205:	learn: 72357.7712376	total: 490ms	remaining: 1.89s
# 206:	learn: 72348.0269461	total: 492ms	remaining: 1.89s
# 207:	learn: 72332.4451599	total: 494ms	remaining: 1.88s
# 208:	learn: 72314.5203143	total: 496ms	remaining: 1.88s
# 209:	learn: 72299.9323861	total: 499ms	remaining: 1.88s
# 210:	learn: 72278.2107747	total: 502ms	remaining: 1.88s
# 211:	learn: 72256.8110504	total: 504ms	remaining: 1.87s
# 212:	learn: 72249.4344428	total: 506ms	remaining: 1.87s
# 213:	learn: 72230.7497978	total: 509ms	remaining: 1.87s
# 214:	learn: 72210.3251845	total: 511ms	remaining: 1.87s
# 215:	learn: 72197.6719069	total: 514ms	remaining: 1.86s
# 216:	learn: 72176.3304992	total: 516ms	remaining: 1.86s
# 217:	learn: 72165.1937751	total: 518ms	remaining: 1.86s
# 218:	learn: 72150.2204423	total: 520ms	remaining: 1.86s
# 219:	learn: 72140.5139052	total: 523ms	remaining: 1.85s
# 220:	learn: 72135.3492716	total: 525ms	remaining: 1.85s
# 221:	learn: 72118.5731745	total: 528ms	remaining: 1.85s
# 222:	learn: 72111.4588522	total: 530ms	remaining: 1.85s
# 223:	learn: 72099.4069970	total: 532ms	remaining: 1.84s
# 224:	learn: 72085.6610789	total: 534ms	remaining: 1.84s
# 225:	learn: 72074.9087327	total: 536ms	remaining: 1.83s
# 226:	learn: 72060.7366259	total: 539ms	remaining: 1.83s
# 227:	learn: 72039.4600620	total: 541ms	remaining: 1.83s
# 228:	learn: 72033.0396293	total: 543ms	remaining: 1.83s
# 229:	learn: 72014.7305120	total: 545ms	remaining: 1.82s
# 230:	learn: 72001.9406923	total: 548ms	remaining: 1.82s
# 231:	learn: 71986.1092790	total: 550ms	remaining: 1.82s
# 232:	learn: 71978.9390052	total: 552ms	remaining: 1.82s
# 233:	learn: 71970.3469225	total: 554ms	remaining: 1.81s
# 234:	learn: 71953.3410703	total: 556ms	remaining: 1.81s
# 235:	learn: 71937.4593767	total: 559ms	remaining: 1.81s
# 236:	learn: 71916.9316700	total: 561ms	remaining: 1.81s
# 237:	learn: 71906.9527321	total: 563ms	remaining: 1.8s
# 238:	learn: 71897.4674975	total: 565ms	remaining: 1.8s
# 239:	learn: 71889.6347999	total: 568ms	remaining: 1.8s
# 240:	learn: 71836.7376241	total: 569ms	remaining: 1.79s
# 241:	learn: 71831.2009660	total: 572ms	remaining: 1.79s
# 242:	learn: 71827.4644717	total: 574ms	remaining: 1.79s
# 243:	learn: 71813.1014412	total: 576ms	remaining: 1.78s
# 244:	learn: 71792.2241629	total: 579ms	remaining: 1.78s
# 245:	learn: 71785.1303894	total: 582ms	remaining: 1.78s
# 246:	learn: 71777.6854705	total: 584ms	remaining: 1.78s
# 247:	learn: 71771.2118629	total: 587ms	remaining: 1.78s
# 248:	learn: 71747.8848402	total: 590ms	remaining: 1.78s
# 249:	learn: 71736.9396239	total: 592ms	remaining: 1.77s
# 250:	learn: 71715.6596465	total: 594ms	remaining: 1.77s
# 251:	learn: 71690.7257200	total: 597ms	remaining: 1.77s
# 252:	learn: 71680.5596946	total: 600ms	remaining: 1.77s
# 253:	learn: 71665.0016596	total: 602ms	remaining: 1.77s
# 254:	learn: 71652.7289901	total: 604ms	remaining: 1.76s
# 255:	learn: 71641.6499912	total: 608ms	remaining: 1.76s
# 256:	learn: 71620.7127953	total: 610ms	remaining: 1.76s
# 257:	learn: 71603.6437897	total: 612ms	remaining: 1.76s
# 258:	learn: 71590.9893555	total: 614ms	remaining: 1.76s
# 259:	learn: 71567.0365880	total: 617ms	remaining: 1.76s
# 260:	learn: 71562.6131518	total: 620ms	remaining: 1.75s
# 261:	learn: 71557.8080750	total: 622ms	remaining: 1.75s
# 262:	learn: 71542.2001269	total: 624ms	remaining: 1.75s
# 263:	learn: 71534.1095848	total: 627ms	remaining: 1.75s
# 264:	learn: 71519.6312348	total: 629ms	remaining: 1.75s
# 265:	learn: 71501.0114313	total: 631ms	remaining: 1.74s
# 266:	learn: 71475.9561456	total: 633ms	remaining: 1.74s
# 267:	learn: 71470.0097030	total: 636ms	remaining: 1.74s
# 268:	learn: 71465.6167870	total: 639ms	remaining: 1.74s
# 269:	learn: 71453.1238900	total: 641ms	remaining: 1.73s
# 270:	learn: 71448.2915218	total: 643ms	remaining: 1.73s
# 271:	learn: 71426.2876600	total: 646ms	remaining: 1.73s
# 272:	learn: 71418.2437960	total: 649ms	remaining: 1.73s
# 273:	learn: 71403.5658118	total: 651ms	remaining: 1.73s
# 274:	learn: 71395.0075235	total: 654ms	remaining: 1.72s
# 275:	learn: 71389.2172180	total: 657ms	remaining: 1.72s
# 276:	learn: 71367.8136087	total: 659ms	remaining: 1.72s
# 277:	learn: 71356.6670942	total: 662ms	remaining: 1.72s
# 278:	learn: 71336.6541993	total: 664ms	remaining: 1.72s
# 279:	learn: 71304.6258778	total: 666ms	remaining: 1.71s
# 280:	learn: 71292.1114267	total: 669ms	remaining: 1.71s
# 281:	learn: 71286.4192874	total: 671ms	remaining: 1.71s
# 282:	learn: 71269.3368119	total: 674ms	remaining: 1.71s
# 283:	learn: 71260.5326278	total: 677ms	remaining: 1.71s
# 284:	learn: 71244.8462309	total: 679ms	remaining: 1.7s
# 285:	learn: 71239.2702337	total: 681ms	remaining: 1.7s
# 286:	learn: 71226.4644399	total: 684ms	remaining: 1.7s
# 287:	learn: 71215.6156914	total: 686ms	remaining: 1.7s
# 288:	learn: 71197.4396678	total: 689ms	remaining: 1.69s
# 289:	learn: 71180.1558111	total: 691ms	remaining: 1.69s
# 290:	learn: 71170.4970243	total: 693ms	remaining: 1.69s
# 291:	learn: 71160.2166614	total: 696ms	remaining: 1.69s
# 292:	learn: 71151.1455003	total: 698ms	remaining: 1.69s
# 293:	learn: 71133.9204514	total: 701ms	remaining: 1.68s
# 294:	learn: 71128.1789536	total: 704ms	remaining: 1.68s
# 295:	learn: 71117.2117716	total: 706ms	remaining: 1.68s
# 296:	learn: 71108.8292619	total: 709ms	remaining: 1.68s
# 297:	learn: 71103.3594086	total: 711ms	remaining: 1.67s
# 298:	learn: 71091.9177446	total: 713ms	remaining: 1.67s
# 299:	learn: 71082.9680652	total: 716ms	remaining: 1.67s
# 300:	learn: 71074.1174234	total: 718ms	remaining: 1.67s
# 301:	learn: 71061.4121048	total: 721ms	remaining: 1.67s
# 302:	learn: 71054.4624532	total: 723ms	remaining: 1.66s
# 303:	learn: 71038.6303386	total: 725ms	remaining: 1.66s
# 304:	learn: 71034.3577352	total: 728ms	remaining: 1.66s
# 305:	learn: 71022.1565179	total: 730ms	remaining: 1.66s
# 306:	learn: 71005.6387707	total: 732ms	remaining: 1.65s
# 307:	learn: 71002.7344848	total: 734ms	remaining: 1.65s
# 308:	learn: 70993.2186904	total: 737ms	remaining: 1.65s
# 309:	learn: 70986.3292214	total: 738ms	remaining: 1.64s
# 310:	learn: 70981.5787419	total: 740ms	remaining: 1.64s
# 311:	learn: 70970.1207884	total: 743ms	remaining: 1.64s
# 312:	learn: 70952.9287165	total: 745ms	remaining: 1.63s
# 313:	learn: 70937.4653358	total: 747ms	remaining: 1.63s
# 314:	learn: 70929.6504138	total: 749ms	remaining: 1.63s
# 315:	learn: 70916.3436617	total: 751ms	remaining: 1.63s
# 316:	learn: 70909.9587464	total: 754ms	remaining: 1.62s
# 317:	learn: 70903.6736614	total: 756ms	remaining: 1.62s
# 318:	learn: 70899.9217557	total: 758ms	remaining: 1.62s
# 319:	learn: 70887.7844365	total: 760ms	remaining: 1.61s
# 320:	learn: 70865.9012162	total: 762ms	remaining: 1.61s
# 321:	learn: 70844.1720196	total: 764ms	remaining: 1.61s
# 322:	learn: 70833.0168070	total: 767ms	remaining: 1.61s
# 323:	learn: 70823.0359251	total: 768ms	remaining: 1.6s
# 324:	learn: 70816.7565294	total: 770ms	remaining: 1.6s
# 325:	learn: 70808.6568280	total: 773ms	remaining: 1.6s
# 326:	learn: 70803.7100921	total: 775ms	remaining: 1.59s
# 327:	learn: 70796.5072143	total: 777ms	remaining: 1.59s
# 328:	learn: 70790.4969933	total: 779ms	remaining: 1.59s
# 329:	learn: 70783.0279205	total: 782ms	remaining: 1.59s
# 330:	learn: 70768.2248932	total: 784ms	remaining: 1.58s
# 331:	learn: 70763.8085321	total: 786ms	remaining: 1.58s
# 332:	learn: 70755.3204309	total: 788ms	remaining: 1.58s
# 333:	learn: 70743.8727933	total: 791ms	remaining: 1.58s
# 334:	learn: 70734.6811428	total: 793ms	remaining: 1.57s
# 335:	learn: 70723.7670229	total: 796ms	remaining: 1.57s
# 336:	learn: 70720.2270373	total: 798ms	remaining: 1.57s
# 337:	learn: 70713.9049539	total: 800ms	remaining: 1.57s
# 338:	learn: 70711.6397387	total: 803ms	remaining: 1.56s
# 339:	learn: 70695.2541994	total: 805ms	remaining: 1.56s
# 340:	learn: 70681.4299328	total: 807ms	remaining: 1.56s
# 341:	learn: 70675.4367868	total: 809ms	remaining: 1.56s
# 342:	learn: 70665.3564112	total: 812ms	remaining: 1.55s
# 343:	learn: 70642.3998905	total: 815ms	remaining: 1.55s
# 344:	learn: 70634.0080670	total: 817ms	remaining: 1.55s
# 345:	learn: 70624.8928393	total: 819ms	remaining: 1.55s
# 346:	learn: 70618.6529507	total: 822ms	remaining: 1.55s
# 347:	learn: 70601.2979863	total: 824ms	remaining: 1.54s
# 348:	learn: 70584.3623654	total: 826ms	remaining: 1.54s
# 349:	learn: 70574.8338724	total: 828ms	remaining: 1.54s
# 350:	learn: 70565.1124080	total: 831ms	remaining: 1.54s
# 351:	learn: 70556.9131897	total: 833ms	remaining: 1.53s
# 352:	learn: 70540.0173741	total: 836ms	remaining: 1.53s
# 353:	learn: 70534.5067745	total: 838ms	remaining: 1.53s
# 354:	learn: 70529.0630368	total: 841ms	remaining: 1.53s
# 355:	learn: 70525.4560767	total: 843ms	remaining: 1.52s
# 356:	learn: 70519.2780562	total: 845ms	remaining: 1.52s
# 357:	learn: 70511.0230260	total: 847ms	remaining: 1.52s
# 358:	learn: 70502.9252250	total: 849ms	remaining: 1.52s
# 359:	learn: 70496.5230632	total: 852ms	remaining: 1.51s
# 360:	learn: 70480.5555175	total: 855ms	remaining: 1.51s
# 361:	learn: 70465.4296397	total: 856ms	remaining: 1.51s
# 362:	learn: 70455.4606790	total: 858ms	remaining: 1.51s
# 363:	learn: 70446.2751887	total: 861ms	remaining: 1.5s
# 364:	learn: 70440.8583206	total: 863ms	remaining: 1.5s
# 365:	learn: 70435.0300060	total: 865ms	remaining: 1.5s
# 366:	learn: 70427.6007325	total: 867ms	remaining: 1.5s
# 367:	learn: 70418.5531439	total: 869ms	remaining: 1.49s
# 368:	learn: 70410.8289193	total: 872ms	remaining: 1.49s
# 369:	learn: 70400.0938058	total: 874ms	remaining: 1.49s
# 370:	learn: 70383.5649346	total: 876ms	remaining: 1.48s
# 371:	learn: 70370.4381851	total: 878ms	remaining: 1.48s
# 372:	learn: 70364.9008152	total: 880ms	remaining: 1.48s
# 373:	learn: 70355.6663996	total: 882ms	remaining: 1.48s
# 374:	learn: 70352.7116703	total: 885ms	remaining: 1.47s
# 375:	learn: 70345.8674200	total: 887ms	remaining: 1.47s
# 376:	learn: 70317.6333297	total: 888ms	remaining: 1.47s
# 377:	learn: 70310.9949182	total: 891ms	remaining: 1.47s
# 378:	learn: 70293.7024067	total: 894ms	remaining: 1.46s
# 379:	learn: 70287.4533731	total: 896ms	remaining: 1.46s
# 380:	learn: 70280.8998999	total: 897ms	remaining: 1.46s
# 381:	learn: 70270.1381832	total: 900ms	remaining: 1.46s
# 382:	learn: 70267.2575320	total: 903ms	remaining: 1.45s
# 383:	learn: 70259.8848233	total: 905ms	remaining: 1.45s
# 384:	learn: 70246.5829458	total: 907ms	remaining: 1.45s
# 385:	learn: 70226.1388125	total: 909ms	remaining: 1.45s
# 386:	learn: 70219.3667116	total: 911ms	remaining: 1.44s
# 387:	learn: 70212.1748634	total: 914ms	remaining: 1.44s
# 388:	learn: 70171.7340375	total: 916ms	remaining: 1.44s
# 389:	learn: 70160.6410246	total: 918ms	remaining: 1.44s
# 390:	learn: 70151.8397710	total: 920ms	remaining: 1.43s
# 391:	learn: 70141.0142706	total: 923ms	remaining: 1.43s
# 392:	learn: 70137.1877332	total: 924ms	remaining: 1.43s
# 393:	learn: 70121.7407450	total: 926ms	remaining: 1.42s
# 394:	learn: 70105.2782592	total: 929ms	remaining: 1.42s
# 395:	learn: 70102.0489383	total: 931ms	remaining: 1.42s
# 396:	learn: 70095.3630263	total: 933ms	remaining: 1.42s
# 397:	learn: 70089.9190381	total: 935ms	remaining: 1.41s
# 398:	learn: 70083.6924661	total: 937ms	remaining: 1.41s
# 399:	learn: 70070.8515888	total: 940ms	remaining: 1.41s
# 400:	learn: 70059.5156629	total: 942ms	remaining: 1.41s
# 401:	learn: 70052.3209538	total: 944ms	remaining: 1.4s
# 402:	learn: 70047.6392538	total: 946ms	remaining: 1.4s
# 403:	learn: 70044.1125279	total: 948ms	remaining: 1.4s
# 404:	learn: 70039.0237016	total: 950ms	remaining: 1.4s
# 405:	learn: 70028.8788261	total: 953ms	remaining: 1.39s
# 406:	learn: 70018.0919307	total: 955ms	remaining: 1.39s
# 407:	learn: 70010.7133201	total: 956ms	remaining: 1.39s
# 408:	learn: 69990.5562930	total: 959ms	remaining: 1.39s
# 409:	learn: 69984.3208805	total: 961ms	remaining: 1.38s
# 410:	learn: 69975.1888472	total: 963ms	remaining: 1.38s
# 411:	learn: 69965.5604334	total: 965ms	remaining: 1.38s
# 412:	learn: 69958.9564543	total: 967ms	remaining: 1.37s
# 413:	learn: 69951.0830998	total: 969ms	remaining: 1.37s
# 414:	learn: 69934.5465093	total: 972ms	remaining: 1.37s
# 415:	learn: 69925.1059390	total: 974ms	remaining: 1.37s
# 416:	learn: 69918.1112222	total: 976ms	remaining: 1.36s
# 417:	learn: 69910.4539031	total: 978ms	remaining: 1.36s
# 418:	learn: 69899.8320574	total: 981ms	remaining: 1.36s
# 419:	learn: 69892.7669064	total: 983ms	remaining: 1.36s
# 420:	learn: 69888.6992826	total: 985ms	remaining: 1.35s
# 421:	learn: 69877.1775908	total: 988ms	remaining: 1.35s
# 422:	learn: 69874.8173281	total: 989ms	remaining: 1.35s
# 423:	learn: 69867.4643441	total: 992ms	remaining: 1.35s
# 424:	learn: 69861.4421324	total: 994ms	remaining: 1.34s
# 425:	learn: 69839.2984829	total: 996ms	remaining: 1.34s
# 426:	learn: 69832.8728607	total: 998ms	remaining: 1.34s
# 427:	learn: 69826.0048444	total: 1s	remaining: 1.34s
# 428:	learn: 69814.9486719	total: 1s	remaining: 1.33s
# 429:	learn: 69811.2980171	total: 1s	remaining: 1.33s
# 430:	learn: 69800.9330600	total: 1.01s	remaining: 1.33s
# 431:	learn: 69787.4960988	total: 1.01s	remaining: 1.33s
# 432:	learn: 69781.6948296	total: 1.01s	remaining: 1.32s
# 433:	learn: 69776.1855578	total: 1.01s	remaining: 1.32s
# 434:	learn: 69771.4581198	total: 1.01s	remaining: 1.32s
# 435:	learn: 69762.0737166	total: 1.02s	remaining: 1.32s
# 436:	learn: 69753.9365974	total: 1.02s	remaining: 1.31s
# 437:	learn: 69743.5869331	total: 1.02s	remaining: 1.31s
# 438:	learn: 69735.2162588	total: 1.02s	remaining: 1.31s
# 439:	learn: 69729.9313279	total: 1.03s	remaining: 1.3s
# 440:	learn: 69708.0931358	total: 1.03s	remaining: 1.3s
# 441:	learn: 69706.2888645	total: 1.03s	remaining: 1.3s
# 442:	learn: 69694.6552997	total: 1.03s	remaining: 1.3s
# 443:	learn: 69690.0551309	total: 1.03s	remaining: 1.29s
# 444:	learn: 69676.3890342	total: 1.04s	remaining: 1.29s
# 445:	learn: 69668.6710857	total: 1.04s	remaining: 1.29s
# 446:	learn: 69655.2188307	total: 1.04s	remaining: 1.29s
# 447:	learn: 69629.7515611	total: 1.04s	remaining: 1.28s
# 448:	learn: 69623.8894312	total: 1.04s	remaining: 1.28s
# 449:	learn: 69608.9012655	total: 1.05s	remaining: 1.28s
# 450:	learn: 69605.7341465	total: 1.05s	remaining: 1.28s
# 451:	learn: 69600.2484511	total: 1.05s	remaining: 1.27s
# 452:	learn: 69593.9405602	total: 1.05s	remaining: 1.27s
# 453:	learn: 69587.5400238	total: 1.05s	remaining: 1.27s
# 454:	learn: 69584.0343127	total: 1.06s	remaining: 1.27s
# 455:	learn: 69563.5080354	total: 1.06s	remaining: 1.26s
# 456:	learn: 69559.2096432	total: 1.06s	remaining: 1.26s
# 457:	learn: 69547.8995090	total: 1.06s	remaining: 1.26s
# 458:	learn: 69534.4989696	total: 1.07s	remaining: 1.26s
# 459:	learn: 69526.8505983	total: 1.07s	remaining: 1.25s
# 460:	learn: 69524.0483739	total: 1.07s	remaining: 1.25s
# 461:	learn: 69516.6241519	total: 1.07s	remaining: 1.25s
# 462:	learn: 69512.3774818	total: 1.07s	remaining: 1.25s
# 463:	learn: 69503.5043811	total: 1.08s	remaining: 1.24s
# 464:	learn: 69492.9466810	total: 1.08s	remaining: 1.24s
# 465:	learn: 69485.5635328	total: 1.08s	remaining: 1.24s
# 466:	learn: 69479.1495971	total: 1.08s	remaining: 1.24s
# 467:	learn: 69469.2816356	total: 1.08s	remaining: 1.23s
# 468:	learn: 69464.3761668	total: 1.09s	remaining: 1.23s
# 469:	learn: 69461.0487227	total: 1.09s	remaining: 1.23s
# 470:	learn: 69453.2214263	total: 1.09s	remaining: 1.23s
# 471:	learn: 69447.6690118	total: 1.09s	remaining: 1.22s
# 472:	learn: 69443.9990492	total: 1.1s	remaining: 1.22s
# 473:	learn: 69440.9884416	total: 1.1s	remaining: 1.22s
# 474:	learn: 69423.2467849	total: 1.1s	remaining: 1.22s
# 475:	learn: 69412.4820097	total: 1.1s	remaining: 1.21s
# 476:	learn: 69408.7896731	total: 1.1s	remaining: 1.21s
# 477:	learn: 69399.0348056	total: 1.11s	remaining: 1.21s
# 478:	learn: 69390.9577088	total: 1.11s	remaining: 1.21s
# 479:	learn: 69387.4181258	total: 1.11s	remaining: 1.2s
# 480:	learn: 69374.7254407	total: 1.11s	remaining: 1.2s
# 481:	learn: 69368.2088919	total: 1.11s	remaining: 1.2s
# 482:	learn: 69365.0136779	total: 1.12s	remaining: 1.2s
# 483:	learn: 69357.3055591	total: 1.12s	remaining: 1.19s
# 484:	learn: 69337.5917321	total: 1.12s	remaining: 1.19s
# 485:	learn: 69331.7973130	total: 1.12s	remaining: 1.19s
# 486:	learn: 69320.5322335	total: 1.13s	remaining: 1.19s
# 487:	learn: 69302.9035540	total: 1.13s	remaining: 1.18s
# 488:	learn: 69292.9693979	total: 1.13s	remaining: 1.18s
# 489:	learn: 69286.4862592	total: 1.13s	remaining: 1.18s
# 490:	learn: 69278.7282992	total: 1.14s	remaining: 1.18s
# 491:	learn: 69274.3163212	total: 1.14s	remaining: 1.17s
# 492:	learn: 69270.3939464	total: 1.14s	remaining: 1.17s
# 493:	learn: 69263.5797909	total: 1.14s	remaining: 1.17s
# 494:	learn: 69258.1389481	total: 1.14s	remaining: 1.17s
# 495:	learn: 69243.9900707	total: 1.15s	remaining: 1.16s
# 496:	learn: 69240.2441949	total: 1.15s	remaining: 1.16s
# 497:	learn: 69236.8682778	total: 1.15s	remaining: 1.16s
# 498:	learn: 69219.2045777	total: 1.15s	remaining: 1.16s
# 499:	learn: 69212.2619519	total: 1.15s	remaining: 1.15s
# 500:	learn: 69204.9448705	total: 1.16s	remaining: 1.15s
# 501:	learn: 69197.0680285	total: 1.16s	remaining: 1.15s
# 502:	learn: 69193.2750280	total: 1.16s	remaining: 1.15s
# 503:	learn: 69187.5748480	total: 1.16s	remaining: 1.14s
# 504:	learn: 69181.0338100	total: 1.17s	remaining: 1.14s
# 505:	learn: 69168.8418874	total: 1.17s	remaining: 1.14s
# 506:	learn: 69166.6598760	total: 1.17s	remaining: 1.14s
# 507:	learn: 69160.8820165	total: 1.17s	remaining: 1.13s
# 508:	learn: 69144.0397526	total: 1.17s	remaining: 1.13s
# 509:	learn: 69129.2050051	total: 1.18s	remaining: 1.13s
# 510:	learn: 69117.0005067	total: 1.18s	remaining: 1.13s
# 511:	learn: 69110.1334562	total: 1.18s	remaining: 1.12s
# 512:	learn: 69101.9401723	total: 1.18s	remaining: 1.12s
# 513:	learn: 69090.0640237	total: 1.19s	remaining: 1.12s
# 514:	learn: 69086.5708523	total: 1.19s	remaining: 1.12s
# 515:	learn: 69076.9937795	total: 1.19s	remaining: 1.11s
# 516:	learn: 69066.8312869	total: 1.19s	remaining: 1.11s
# 517:	learn: 69046.7286469	total: 1.19s	remaining: 1.11s
# 518:	learn: 69038.4728421	total: 1.2s	remaining: 1.11s
# 519:	learn: 69026.8023582	total: 1.2s	remaining: 1.11s
# 520:	learn: 69018.6610704	total: 1.2s	remaining: 1.1s
# 521:	learn: 68998.5065643	total: 1.2s	remaining: 1.1s
# 522:	learn: 68987.1010656	total: 1.2s	remaining: 1.1s
# 523:	learn: 68979.7084973	total: 1.21s	remaining: 1.1s
# 524:	learn: 68977.7682039	total: 1.21s	remaining: 1.09s
# 525:	learn: 68969.9823996	total: 1.21s	remaining: 1.09s
# 526:	learn: 68965.0104475	total: 1.21s	remaining: 1.09s
# 527:	learn: 68960.3271945	total: 1.22s	remaining: 1.09s
# 528:	learn: 68955.3029251	total: 1.22s	remaining: 1.08s
# 529:	learn: 68947.2185891	total: 1.22s	remaining: 1.08s
# 530:	learn: 68942.5754320	total: 1.22s	remaining: 1.08s
# 531:	learn: 68933.9766771	total: 1.22s	remaining: 1.08s
# 532:	learn: 68929.0675395	total: 1.23s	remaining: 1.07s
# 533:	learn: 68915.8049230	total: 1.23s	remaining: 1.07s
# 534:	learn: 68912.0067722	total: 1.23s	remaining: 1.07s
# 535:	learn: 68906.2006720	total: 1.23s	remaining: 1.07s
# 536:	learn: 68892.9922103	total: 1.23s	remaining: 1.06s
# 537:	learn: 68886.8848085	total: 1.24s	remaining: 1.06s
# 538:	learn: 68882.4821830	total: 1.24s	remaining: 1.06s
# 539:	learn: 68879.8363385	total: 1.24s	remaining: 1.06s
# 540:	learn: 68873.3418750	total: 1.24s	remaining: 1.05s
# 541:	learn: 68857.9766715	total: 1.25s	remaining: 1.05s
# 542:	learn: 68850.0808143	total: 1.25s	remaining: 1.05s
# 543:	learn: 68843.8351737	total: 1.25s	remaining: 1.05s
# 544:	learn: 68820.7606837	total: 1.25s	remaining: 1.04s
# 545:	learn: 68811.1535129	total: 1.25s	remaining: 1.04s
# 546:	learn: 68798.5580181	total: 1.26s	remaining: 1.04s
# 547:	learn: 68794.6982031	total: 1.26s	remaining: 1.04s
# 548:	learn: 68786.6674383	total: 1.26s	remaining: 1.03s
# 549:	learn: 68781.9133909	total: 1.26s	remaining: 1.03s
# 550:	learn: 68775.5062919	total: 1.26s	remaining: 1.03s
# 551:	learn: 68773.9570437	total: 1.27s	remaining: 1.03s
# 552:	learn: 68765.1784618	total: 1.27s	remaining: 1.02s
# 553:	learn: 68756.9923907	total: 1.27s	remaining: 1.02s
# 554:	learn: 68749.8270530	total: 1.27s	remaining: 1.02s
# 555:	learn: 68731.6549486	total: 1.27s	remaining: 1.02s
# 556:	learn: 68725.3087697	total: 1.28s	remaining: 1.02s
# 557:	learn: 68718.2471800	total: 1.28s	remaining: 1.01s
# 558:	learn: 68706.8158806	total: 1.28s	remaining: 1.01s
# 559:	learn: 68694.4776132	total: 1.28s	remaining: 1.01s
# 560:	learn: 68690.2664823	total: 1.29s	remaining: 1.01s
# 561:	learn: 68683.6608085	total: 1.29s	remaining: 1s
# 562:	learn: 68671.2872801	total: 1.29s	remaining: 1s
# 563:	learn: 68666.5459797	total: 1.29s	remaining: 999ms
# 564:	learn: 68660.2698192	total: 1.29s	remaining: 997ms
# 565:	learn: 68654.4908204	total: 1.3s	remaining: 995ms
# 566:	learn: 68652.3304837	total: 1.3s	remaining: 992ms
# 567:	learn: 68639.7611602	total: 1.3s	remaining: 990ms
# 568:	learn: 68632.8774778	total: 1.3s	remaining: 988ms
# 569:	learn: 68630.2220104	total: 1.31s	remaining: 986ms
# 570:	learn: 68624.1534669	total: 1.31s	remaining: 983ms
# 571:	learn: 68614.0414935	total: 1.31s	remaining: 981ms
# 572:	learn: 68606.9615335	total: 1.31s	remaining: 979ms
# 573:	learn: 68600.8321261	total: 1.32s	remaining: 977ms
# 574:	learn: 68595.8264984	total: 1.32s	remaining: 975ms
# 575:	learn: 68588.3260214	total: 1.32s	remaining: 973ms
# 576:	learn: 68582.9769330	total: 1.32s	remaining: 971ms
# 577:	learn: 68566.3491916	total: 1.32s	remaining: 968ms
# 578:	learn: 68559.8008037	total: 1.33s	remaining: 966ms
# 579:	learn: 68557.2428861	total: 1.33s	remaining: 964ms
# 580:	learn: 68544.3341571	total: 1.33s	remaining: 961ms
# 581:	learn: 68539.1028161	total: 1.33s	remaining: 959ms
# 582:	learn: 68528.6804901	total: 1.34s	remaining: 957ms
# 583:	learn: 68524.4799484	total: 1.34s	remaining: 955ms
# 584:	learn: 68518.1318977	total: 1.34s	remaining: 952ms
# 585:	learn: 68511.3364421	total: 1.34s	remaining: 950ms
# 586:	learn: 68508.6208422	total: 1.35s	remaining: 948ms
# 587:	learn: 68490.1110230	total: 1.35s	remaining: 945ms
# 588:	learn: 68472.4210358	total: 1.35s	remaining: 943ms
# 589:	learn: 68460.4946085	total: 1.35s	remaining: 941ms
# 590:	learn: 68452.3691682	total: 1.36s	remaining: 939ms
# 591:	learn: 68445.8410787	total: 1.36s	remaining: 936ms
# 592:	learn: 68441.4066151	total: 1.36s	remaining: 934ms
# 593:	learn: 68419.3132263	total: 1.36s	remaining: 932ms
# 594:	learn: 68414.9776322	total: 1.36s	remaining: 930ms
# 595:	learn: 68410.2289743	total: 1.37s	remaining: 927ms
# 596:	learn: 68405.4001981	total: 1.37s	remaining: 925ms
# 597:	learn: 68391.0818444	total: 1.37s	remaining: 923ms
# 598:	learn: 68385.4501318	total: 1.38s	remaining: 921ms
# 599:	learn: 68378.6241382	total: 1.38s	remaining: 918ms
# 600:	learn: 68374.9106780	total: 1.38s	remaining: 916ms
# 601:	learn: 68373.3558236	total: 1.38s	remaining: 914ms
# 602:	learn: 68366.8791969	total: 1.38s	remaining: 912ms
# 603:	learn: 68357.4755422	total: 1.39s	remaining: 909ms
# 604:	learn: 68352.2819765	total: 1.39s	remaining: 907ms
# 605:	learn: 68347.9976821	total: 1.39s	remaining: 905ms
# 606:	learn: 68341.0637777	total: 1.39s	remaining: 903ms
# 607:	learn: 68338.4907278	total: 1.4s	remaining: 900ms
# 608:	learn: 68334.0388797	total: 1.4s	remaining: 898ms
# 609:	learn: 68327.4161321	total: 1.4s	remaining: 896ms
# 610:	learn: 68319.8792410	total: 1.4s	remaining: 894ms
# 611:	learn: 68313.6198634	total: 1.41s	remaining: 891ms
# 612:	learn: 68303.4306489	total: 1.41s	remaining: 889ms
# 613:	learn: 68292.8542138	total: 1.41s	remaining: 887ms
# 614:	learn: 68285.1814513	total: 1.41s	remaining: 885ms
# 615:	learn: 68243.3865926	total: 1.42s	remaining: 882ms
# 616:	learn: 68237.9756890	total: 1.42s	remaining: 880ms
# 617:	learn: 68232.1052776	total: 1.42s	remaining: 878ms
# 618:	learn: 68228.7699077	total: 1.42s	remaining: 875ms
# 619:	learn: 68218.5888912	total: 1.42s	remaining: 873ms
# 620:	learn: 68214.3170728	total: 1.43s	remaining: 870ms
# 621:	learn: 68196.1171026	total: 1.43s	remaining: 868ms
# 622:	learn: 68186.8639077	total: 1.43s	remaining: 866ms
# 623:	learn: 68180.6132017	total: 1.43s	remaining: 864ms
# 624:	learn: 68176.9098404	total: 1.44s	remaining: 861ms
# 625:	learn: 68169.7148597	total: 1.44s	remaining: 859ms
# 626:	learn: 68164.5313575	total: 1.44s	remaining: 857ms
# 627:	learn: 68161.2901629	total: 1.44s	remaining: 855ms
# 628:	learn: 68158.0801491	total: 1.44s	remaining: 852ms
# 629:	learn: 68154.4417186	total: 1.45s	remaining: 850ms
# 630:	learn: 68147.5020489	total: 1.45s	remaining: 848ms
# 631:	learn: 68133.3558875	total: 1.45s	remaining: 845ms
# 632:	learn: 68121.8264396	total: 1.45s	remaining: 843ms
# 633:	learn: 68113.8034397	total: 1.46s	remaining: 840ms
# 634:	learn: 68110.3473014	total: 1.46s	remaining: 838ms
# 635:	learn: 68106.0512722	total: 1.46s	remaining: 836ms
# 636:	learn: 68102.8038098	total: 1.46s	remaining: 834ms
# 637:	learn: 68094.5764445	total: 1.47s	remaining: 831ms
# 638:	learn: 68080.9560709	total: 1.47s	remaining: 829ms
# 639:	learn: 68071.2793495	total: 1.47s	remaining: 827ms
# 640:	learn: 68056.8872139	total: 1.47s	remaining: 825ms
# 641:	learn: 68049.8120567	total: 1.47s	remaining: 822ms
# 642:	learn: 68041.7212761	total: 1.48s	remaining: 820ms
# 643:	learn: 68032.4122007	total: 1.48s	remaining: 818ms
# 644:	learn: 68028.2821768	total: 1.48s	remaining: 816ms
# 645:	learn: 68024.9996056	total: 1.48s	remaining: 813ms
# 646:	learn: 68011.1175666	total: 1.49s	remaining: 811ms
# 647:	learn: 68007.2409747	total: 1.49s	remaining: 809ms
# 648:	learn: 67998.1993874	total: 1.49s	remaining: 806ms
# 649:	learn: 67992.1547072	total: 1.49s	remaining: 804ms
# 650:	learn: 67988.0047859	total: 1.5s	remaining: 802ms
# 651:	learn: 67982.9924322	total: 1.5s	remaining: 799ms
# 652:	learn: 67979.4842629	total: 1.5s	remaining: 797ms
# 653:	learn: 67974.7994401	total: 1.5s	remaining: 795ms
# 654:	learn: 67971.0150405	total: 1.5s	remaining: 792ms
# 655:	learn: 67965.2088591	total: 1.51s	remaining: 790ms
# 656:	learn: 67949.7291039	total: 1.51s	remaining: 788ms
# 657:	learn: 67940.6868485	total: 1.51s	remaining: 786ms
# 658:	learn: 67932.5795778	total: 1.51s	remaining: 783ms
# 659:	learn: 67924.0625831	total: 1.51s	remaining: 781ms
# 660:	learn: 67921.7148070	total: 1.52s	remaining: 779ms
# 661:	learn: 67912.8994411	total: 1.52s	remaining: 777ms
# 662:	learn: 67902.7724123	total: 1.52s	remaining: 774ms
# 663:	learn: 67898.4178148	total: 1.52s	remaining: 772ms
# 664:	learn: 67893.2380664	total: 1.53s	remaining: 770ms
# 665:	learn: 67884.4854207	total: 1.53s	remaining: 767ms
# 666:	learn: 67874.2562584	total: 1.53s	remaining: 765ms
# 667:	learn: 67864.7388865	total: 1.53s	remaining: 762ms
# 668:	learn: 67856.7694210	total: 1.54s	remaining: 760ms
# 669:	learn: 67846.1828168	total: 1.54s	remaining: 758ms
# 670:	learn: 67832.4286063	total: 1.54s	remaining: 756ms
# 671:	learn: 67828.5557961	total: 1.54s	remaining: 753ms
# 672:	learn: 67821.7647253	total: 1.54s	remaining: 751ms
# 673:	learn: 67810.7492191	total: 1.55s	remaining: 749ms
# 674:	learn: 67807.2216393	total: 1.55s	remaining: 747ms
# 675:	learn: 67798.5068908	total: 1.55s	remaining: 744ms
# 676:	learn: 67794.9121682	total: 1.55s	remaining: 742ms
# 677:	learn: 67785.9122750	total: 1.56s	remaining: 740ms
# 678:	learn: 67771.5120609	total: 1.56s	remaining: 737ms
# 679:	learn: 67767.6217626	total: 1.56s	remaining: 735ms
# 680:	learn: 67760.0926482	total: 1.56s	remaining: 733ms
# 681:	learn: 67752.4716321	total: 1.57s	remaining: 730ms
# 682:	learn: 67745.5678487	total: 1.57s	remaining: 728ms
# 683:	learn: 67743.4661006	total: 1.57s	remaining: 726ms
# 684:	learn: 67741.0034695	total: 1.57s	remaining: 723ms
# 685:	learn: 67734.7081151	total: 1.58s	remaining: 721ms
# 686:	learn: 67730.1675297	total: 1.58s	remaining: 719ms
# 687:	learn: 67725.6301438	total: 1.58s	remaining: 717ms
# 688:	learn: 67722.7218524	total: 1.58s	remaining: 714ms
# 689:	learn: 67718.9584080	total: 1.58s	remaining: 712ms
# 690:	learn: 67713.8174994	total: 1.59s	remaining: 710ms
# 691:	learn: 67707.3934434	total: 1.59s	remaining: 708ms
# 692:	learn: 67703.0122591	total: 1.59s	remaining: 705ms
# 693:	learn: 67696.2997348	total: 1.59s	remaining: 703ms
# 694:	learn: 67689.2745319	total: 1.6s	remaining: 701ms
# 695:	learn: 67677.5326823	total: 1.6s	remaining: 699ms
# 696:	learn: 67673.3319082	total: 1.6s	remaining: 696ms
# 697:	learn: 67668.5522462	total: 1.6s	remaining: 694ms
# 698:	learn: 67652.0996325	total: 1.61s	remaining: 692ms
# 699:	learn: 67646.7221167	total: 1.61s	remaining: 690ms
# 700:	learn: 67641.0740372	total: 1.61s	remaining: 687ms
# 701:	learn: 67634.7728901	total: 1.61s	remaining: 685ms
# 702:	learn: 67631.6115701	total: 1.61s	remaining: 683ms
# 703:	learn: 67627.0289726	total: 1.62s	remaining: 680ms
# 704:	learn: 67621.4669805	total: 1.62s	remaining: 678ms
# 705:	learn: 67615.8659255	total: 1.62s	remaining: 675ms
# 706:	learn: 67608.0496428	total: 1.62s	remaining: 673ms
# 707:	learn: 67593.4184460	total: 1.63s	remaining: 671ms
# 708:	learn: 67589.3002180	total: 1.63s	remaining: 669ms
# 709:	learn: 67585.6452121	total: 1.63s	remaining: 666ms
# 710:	learn: 67583.2891910	total: 1.63s	remaining: 664ms
# 711:	learn: 67574.3032536	total: 1.64s	remaining: 662ms
# 712:	learn: 67571.7782676	total: 1.64s	remaining: 660ms
# 713:	learn: 67570.5245190	total: 1.64s	remaining: 657ms
# 714:	learn: 67563.0752978	total: 1.64s	remaining: 655ms
# 715:	learn: 67557.8066116	total: 1.65s	remaining: 653ms
# 716:	learn: 67554.6768174	total: 1.65s	remaining: 650ms
# 717:	learn: 67550.7880832	total: 1.65s	remaining: 648ms
# 718:	learn: 67545.3392634	total: 1.65s	remaining: 646ms
# 719:	learn: 67542.4056420	total: 1.65s	remaining: 643ms
# 720:	learn: 67526.5126847	total: 1.66s	remaining: 641ms
# 721:	learn: 67522.8894243	total: 1.66s	remaining: 639ms
# 722:	learn: 67520.5769023	total: 1.66s	remaining: 636ms
# 723:	learn: 67515.9937981	total: 1.66s	remaining: 634ms
# 724:	learn: 67514.6616871	total: 1.67s	remaining: 632ms
# 725:	learn: 67512.9112745	total: 1.67s	remaining: 630ms
# 726:	learn: 67510.0781813	total: 1.67s	remaining: 627ms
# 727:	learn: 67501.0754667	total: 1.67s	remaining: 625ms
# 728:	learn: 67494.5467810	total: 1.68s	remaining: 623ms
# 729:	learn: 67483.0277533	total: 1.68s	remaining: 621ms
# 730:	learn: 67467.3846068	total: 1.68s	remaining: 618ms
# 731:	learn: 67454.2286140	total: 1.68s	remaining: 616ms
# 732:	learn: 67448.5010861	total: 1.68s	remaining: 614ms
# 733:	learn: 67441.1193163	total: 1.69s	remaining: 611ms
# 734:	learn: 67435.7284953	total: 1.69s	remaining: 609ms
# 735:	learn: 67427.6836883	total: 1.69s	remaining: 607ms
# 736:	learn: 67419.9723008	total: 1.69s	remaining: 604ms
# 737:	learn: 67409.2642929	total: 1.7s	remaining: 602ms
# 738:	learn: 67401.3712402	total: 1.7s	remaining: 600ms
# 739:	learn: 67396.6532741	total: 1.7s	remaining: 597ms
# 740:	learn: 67392.0863908	total: 1.7s	remaining: 595ms
# 741:	learn: 67385.7901337	total: 1.7s	remaining: 593ms
# 742:	learn: 67382.2226979	total: 1.71s	remaining: 591ms
# 743:	learn: 67376.7391138	total: 1.71s	remaining: 588ms
# 744:	learn: 67371.4452885	total: 1.71s	remaining: 586ms
# 745:	learn: 67368.9549686	total: 1.71s	remaining: 584ms
# 746:	learn: 67361.0466241	total: 1.72s	remaining: 581ms
# 747:	learn: 67353.6306068	total: 1.72s	remaining: 579ms
# 748:	learn: 67351.4813946	total: 1.72s	remaining: 577ms
# 749:	learn: 67336.8966492	total: 1.72s	remaining: 574ms
# 750:	learn: 67317.0494151	total: 1.73s	remaining: 572ms
# 751:	learn: 67306.0923350	total: 1.73s	remaining: 570ms
# 752:	learn: 67300.4297728	total: 1.73s	remaining: 567ms
# 753:	learn: 67292.2806294	total: 1.73s	remaining: 565ms
# 754:	learn: 67285.2273505	total: 1.73s	remaining: 563ms
# 755:	learn: 67270.3671986	total: 1.74s	remaining: 561ms
# 756:	learn: 67267.2451971	total: 1.74s	remaining: 558ms
# 757:	learn: 67264.2324165	total: 1.74s	remaining: 556ms
# 758:	learn: 67260.9972313	total: 1.74s	remaining: 554ms
# 759:	learn: 67255.8989410	total: 1.75s	remaining: 552ms
# 760:	learn: 67248.5066158	total: 1.75s	remaining: 549ms
# 761:	learn: 67240.4535258	total: 1.75s	remaining: 547ms
# 762:	learn: 67222.8618275	total: 1.75s	remaining: 545ms
# 763:	learn: 67215.2505089	total: 1.75s	remaining: 542ms
# 764:	learn: 67210.8548976	total: 1.76s	remaining: 540ms
# 765:	learn: 67205.7881134	total: 1.76s	remaining: 538ms
# 766:	learn: 67203.5458953	total: 1.76s	remaining: 535ms
# 767:	learn: 67198.7045678	total: 1.76s	remaining: 533ms
# 768:	learn: 67189.6848554	total: 1.77s	remaining: 531ms
# 769:	learn: 67170.8186523	total: 1.77s	remaining: 528ms
# 770:	learn: 67167.6178308	total: 1.77s	remaining: 526ms
# 771:	learn: 67165.1411523	total: 1.77s	remaining: 524ms
# 772:	learn: 67160.1345204	total: 1.78s	remaining: 522ms
# 773:	learn: 67146.0842785	total: 1.78s	remaining: 519ms
# 774:	learn: 67142.8221947	total: 1.78s	remaining: 517ms
# 775:	learn: 67135.9546899	total: 1.78s	remaining: 515ms
# 776:	learn: 67132.9536914	total: 1.78s	remaining: 512ms
# 777:	learn: 67128.0542465	total: 1.79s	remaining: 510ms
# 778:	learn: 67113.1592934	total: 1.79s	remaining: 508ms
# 779:	learn: 67108.1664641	total: 1.79s	remaining: 506ms
# 780:	learn: 67100.4042106	total: 1.79s	remaining: 503ms
# 781:	learn: 67096.9312397	total: 1.8s	remaining: 501ms
# 782:	learn: 67093.6703030	total: 1.8s	remaining: 499ms
# 783:	learn: 67089.6133633	total: 1.8s	remaining: 496ms
# 784:	learn: 67085.0715634	total: 1.8s	remaining: 494ms
# 785:	learn: 67077.0872961	total: 1.81s	remaining: 492ms
# 786:	learn: 67064.3713524	total: 1.81s	remaining: 489ms
# 787:	learn: 67060.0260087	total: 1.81s	remaining: 487ms
# 788:	learn: 67055.2663311	total: 1.81s	remaining: 485ms
# 789:	learn: 67042.6418175	total: 1.81s	remaining: 483ms
# 790:	learn: 67039.6684996	total: 1.82s	remaining: 480ms
# 791:	learn: 67007.8776120	total: 1.82s	remaining: 478ms
# 792:	learn: 67005.1542031	total: 1.82s	remaining: 476ms
# 793:	learn: 67001.5452501	total: 1.82s	remaining: 473ms
# 794:	learn: 66994.3373874	total: 1.83s	remaining: 471ms
# 795:	learn: 66991.2096066	total: 1.83s	remaining: 469ms
# 796:	learn: 66961.1145231	total: 1.83s	remaining: 466ms
# 797:	learn: 66949.7022078	total: 1.83s	remaining: 464ms
# 798:	learn: 66911.6447347	total: 1.83s	remaining: 462ms
# 799:	learn: 66901.1816963	total: 1.84s	remaining: 459ms
# 800:	learn: 66895.8147640	total: 1.84s	remaining: 457ms
# 801:	learn: 66892.3524563	total: 1.84s	remaining: 455ms
# 802:	learn: 66881.2903174	total: 1.84s	remaining: 453ms
# 803:	learn: 66874.5307977	total: 1.85s	remaining: 450ms
# 804:	learn: 66871.2022373	total: 1.85s	remaining: 448ms
# 805:	learn: 66865.2757120	total: 1.85s	remaining: 446ms
# 806:	learn: 66859.8987990	total: 1.85s	remaining: 443ms
# 807:	learn: 66844.1453264	total: 1.85s	remaining: 441ms
# 808:	learn: 66840.3927688	total: 1.86s	remaining: 439ms
# 809:	learn: 66835.5286864	total: 1.86s	remaining: 436ms
# 810:	learn: 66833.4657825	total: 1.86s	remaining: 434ms
# 811:	learn: 66830.6074369	total: 1.86s	remaining: 432ms
# 812:	learn: 66824.0984745	total: 1.87s	remaining: 429ms
# 813:	learn: 66819.7019917	total: 1.87s	remaining: 427ms
# 814:	learn: 66811.6895635	total: 1.87s	remaining: 425ms
# 815:	learn: 66803.8999654	total: 1.87s	remaining: 422ms
# 816:	learn: 66798.1450962	total: 1.88s	remaining: 420ms
# 817:	learn: 66792.1197142	total: 1.88s	remaining: 418ms
# 818:	learn: 66784.9993994	total: 1.88s	remaining: 415ms
# 819:	learn: 66778.1732752	total: 1.88s	remaining: 413ms
# 820:	learn: 66772.1603067	total: 1.88s	remaining: 411ms
# 821:	learn: 66768.7164656	total: 1.89s	remaining: 409ms
# 822:	learn: 66764.7144209	total: 1.89s	remaining: 406ms
# 823:	learn: 66753.8230953	total: 1.89s	remaining: 404ms
# 824:	learn: 66747.7617153	total: 1.89s	remaining: 402ms
# 825:	learn: 66742.3788906	total: 1.9s	remaining: 399ms
# 826:	learn: 66740.5940009	total: 1.9s	remaining: 397ms
# 827:	learn: 66736.1813494	total: 1.9s	remaining: 395ms
# 828:	learn: 66716.1554102	total: 1.9s	remaining: 392ms
# 829:	learn: 66711.3249552	total: 1.9s	remaining: 390ms
# 830:	learn: 66708.6001114	total: 1.91s	remaining: 388ms
# 831:	learn: 66705.4589326	total: 1.91s	remaining: 385ms
# 832:	learn: 66699.4678712	total: 1.91s	remaining: 383ms
# 833:	learn: 66693.7075489	total: 1.91s	remaining: 381ms
# 834:	learn: 66689.0142440	total: 1.92s	remaining: 378ms
# 835:	learn: 66680.5626156	total: 1.92s	remaining: 376ms
# 836:	learn: 66677.2172542	total: 1.92s	remaining: 374ms
# 837:	learn: 66675.1031839	total: 1.92s	remaining: 372ms
# 838:	learn: 66664.2399341	total: 1.92s	remaining: 369ms
# 839:	learn: 66659.7439102	total: 1.93s	remaining: 367ms
# 840:	learn: 66653.7416193	total: 1.93s	remaining: 365ms
# 841:	learn: 66647.4824272	total: 1.93s	remaining: 362ms
# 842:	learn: 66634.2464658	total: 1.93s	remaining: 360ms
# 843:	learn: 66630.3040127	total: 1.93s	remaining: 358ms
# 844:	learn: 66619.8537808	total: 1.94s	remaining: 355ms
# 845:	learn: 66611.2223772	total: 1.94s	remaining: 353ms
# 846:	learn: 66608.6786961	total: 1.94s	remaining: 351ms
# 847:	learn: 66603.6124201	total: 1.94s	remaining: 348ms
# 848:	learn: 66598.2072549	total: 1.95s	remaining: 346ms
# 849:	learn: 66594.2377243	total: 1.95s	remaining: 344ms
# 850:	learn: 66581.1479996	total: 1.95s	remaining: 341ms
# 851:	learn: 66575.5734831	total: 1.95s	remaining: 339ms
# 852:	learn: 66571.1855398	total: 1.95s	remaining: 337ms
# 853:	learn: 66566.0308520	total: 1.96s	remaining: 334ms
# 854:	learn: 66563.0790253	total: 1.96s	remaining: 332ms
# 855:	learn: 66558.5832986	total: 1.96s	remaining: 330ms
# 856:	learn: 66554.4866107	total: 1.96s	remaining: 328ms
# 857:	learn: 66550.5144723	total: 1.97s	remaining: 325ms
# 858:	learn: 66541.8098824	total: 1.97s	remaining: 323ms
# 859:	learn: 66534.1741529	total: 1.97s	remaining: 321ms
# 860:	learn: 66528.6385037	total: 1.97s	remaining: 318ms
# 861:	learn: 66524.3295094	total: 1.97s	remaining: 316ms
# 862:	learn: 66519.5992821	total: 1.98s	remaining: 314ms
# 863:	learn: 66515.1077519	total: 1.98s	remaining: 312ms
# 864:	learn: 66510.5231530	total: 1.98s	remaining: 309ms
# 865:	learn: 66504.7393287	total: 1.98s	remaining: 307ms
# 866:	learn: 66502.2058481	total: 1.99s	remaining: 305ms
# 867:	learn: 66496.7246359	total: 1.99s	remaining: 303ms
# 868:	learn: 66492.0031515	total: 1.99s	remaining: 300ms
# 869:	learn: 66486.6602965	total: 1.99s	remaining: 298ms
# 870:	learn: 66482.4413862	total: 2s	remaining: 296ms
# 871:	learn: 66476.1553557	total: 2s	remaining: 293ms
# 872:	learn: 66471.0040086	total: 2s	remaining: 291ms
# 873:	learn: 66469.6045439	total: 2s	remaining: 289ms
# 874:	learn: 66459.0612005	total: 2s	remaining: 286ms
# 875:	learn: 66457.2508477	total: 2.01s	remaining: 284ms
# 876:	learn: 66455.4547290	total: 2.01s	remaining: 282ms
# 877:	learn: 66448.8661642	total: 2.01s	remaining: 280ms
# 878:	learn: 66441.6733482	total: 2.01s	remaining: 277ms
# 879:	learn: 66435.5942044	total: 2.02s	remaining: 275ms
# 880:	learn: 66432.4794099	total: 2.02s	remaining: 273ms
# 881:	learn: 66421.8837290	total: 2.02s	remaining: 270ms
# 882:	learn: 66417.9250975	total: 2.02s	remaining: 268ms
# 883:	learn: 66407.9595917	total: 2.03s	remaining: 266ms
# 884:	learn: 66402.9244596	total: 2.03s	remaining: 264ms
# 885:	learn: 66400.7123113	total: 2.03s	remaining: 261ms
# 886:	learn: 66390.4118072	total: 2.03s	remaining: 259ms
# 887:	learn: 66386.5764091	total: 2.04s	remaining: 257ms
# 888:	learn: 66372.0299076	total: 2.04s	remaining: 254ms
# 889:	learn: 66368.2363538	total: 2.04s	remaining: 252ms
# 890:	learn: 66363.0408713	total: 2.04s	remaining: 250ms
# 891:	learn: 66347.1121977	total: 2.04s	remaining: 248ms
# 892:	learn: 66344.5941588	total: 2.05s	remaining: 245ms
# 893:	learn: 66329.4696076	total: 2.05s	remaining: 243ms
# 894:	learn: 66326.8686100	total: 2.05s	remaining: 241ms
# 895:	learn: 66320.7789429	total: 2.05s	remaining: 238ms
# 896:	learn: 66310.5232809	total: 2.06s	remaining: 236ms
# 897:	learn: 66301.1536728	total: 2.06s	remaining: 234ms
# 898:	learn: 66290.9307718	total: 2.06s	remaining: 232ms
# 899:	learn: 66288.6289699	total: 2.06s	remaining: 229ms
# 900:	learn: 66285.9297100	total: 2.06s	remaining: 227ms
# 901:	learn: 66275.2497299	total: 2.07s	remaining: 225ms
# 902:	learn: 66273.2302576	total: 2.07s	remaining: 222ms
# 903:	learn: 66266.3800642	total: 2.07s	remaining: 220ms
# 904:	learn: 66260.6823698	total: 2.07s	remaining: 218ms
# 905:	learn: 66257.4519067	total: 2.08s	remaining: 215ms
# 906:	learn: 66249.7511657	total: 2.08s	remaining: 213ms
# 907:	learn: 66246.5488266	total: 2.08s	remaining: 211ms
# 908:	learn: 66242.6943518	total: 2.08s	remaining: 209ms
# 909:	learn: 66241.2148331	total: 2.09s	remaining: 206ms
# 910:	learn: 66233.1360064	total: 2.09s	remaining: 204ms
# 911:	learn: 66219.6953844	total: 2.09s	remaining: 202ms
# 912:	learn: 66216.1081296	total: 2.09s	remaining: 199ms
# 913:	learn: 66208.8470173	total: 2.1s	remaining: 197ms
# 914:	learn: 66205.3057714	total: 2.1s	remaining: 195ms
# 915:	learn: 66201.1943910	total: 2.1s	remaining: 193ms
# 916:	learn: 66196.0539102	total: 2.1s	remaining: 190ms
# 917:	learn: 66189.9988151	total: 2.1s	remaining: 188ms
# 918:	learn: 66184.8897339	total: 2.1s	remaining: 186ms
# 919:	learn: 66166.9133890	total: 2.11s	remaining: 183ms
# 920:	learn: 66162.6991965	total: 2.11s	remaining: 181ms
# 921:	learn: 66160.0306668	total: 2.11s	remaining: 179ms
# 922:	learn: 66153.8287890	total: 2.11s	remaining: 176ms
# 923:	learn: 66134.9146725	total: 2.12s	remaining: 174ms
# 924:	learn: 66131.9184845	total: 2.12s	remaining: 172ms
# 925:	learn: 66130.5226092	total: 2.12s	remaining: 169ms
# 926:	learn: 66122.6599438	total: 2.12s	remaining: 167ms
# 927:	learn: 66112.2658668	total: 2.13s	remaining: 165ms
# 928:	learn: 66109.8824641	total: 2.13s	remaining: 163ms
# 929:	learn: 66101.1844691	total: 2.13s	remaining: 160ms
# 930:	learn: 66093.9430447	total: 2.13s	remaining: 158ms
# 931:	learn: 66089.2143291	total: 2.13s	remaining: 156ms
# 932:	learn: 66084.0112737	total: 2.14s	remaining: 153ms
# 933:	learn: 66081.7633122	total: 2.14s	remaining: 151ms
# 934:	learn: 66076.1035688	total: 2.14s	remaining: 149ms
# 935:	learn: 66067.2610450	total: 2.14s	remaining: 147ms
# 936:	learn: 66060.5008520	total: 2.15s	remaining: 144ms
# 937:	learn: 66044.9878687	total: 2.15s	remaining: 142ms
# 938:	learn: 66038.6027039	total: 2.15s	remaining: 140ms
# 939:	learn: 66035.2032592	total: 2.15s	remaining: 137ms
# 940:	learn: 66030.7290931	total: 2.15s	remaining: 135ms
# 941:	learn: 66028.5404147	total: 2.16s	remaining: 133ms
# 942:	learn: 66025.3237524	total: 2.16s	remaining: 131ms
# 943:	learn: 66023.9220293	total: 2.16s	remaining: 128ms
# 944:	learn: 66019.6663594	total: 2.16s	remaining: 126ms
# 945:	learn: 66010.4100490	total: 2.17s	remaining: 124ms
# 946:	learn: 66005.8083710	total: 2.17s	remaining: 121ms
# 947:	learn: 65997.2009338	total: 2.17s	remaining: 119ms
# 948:	learn: 65991.6957561	total: 2.17s	remaining: 117ms
# 949:	learn: 65982.4786794	total: 2.18s	remaining: 115ms
# 950:	learn: 65979.3353007	total: 2.18s	remaining: 112ms
# 951:	learn: 65968.8862666	total: 2.18s	remaining: 110ms
# 952:	learn: 65967.1092266	total: 2.18s	remaining: 108ms
# 953:	learn: 65962.8894642	total: 2.19s	remaining: 105ms
# 954:	learn: 65958.7989509	total: 2.19s	remaining: 103ms
# 955:	learn: 65952.4486189	total: 2.19s	remaining: 101ms
# 956:	learn: 65945.7018456	total: 2.19s	remaining: 98.5ms
# 957:	learn: 65940.6386136	total: 2.19s	remaining: 96.2ms
# 958:	learn: 65939.0767421	total: 2.2s	remaining: 93.9ms
# 959:	learn: 65934.3117261	total: 2.2s	remaining: 91.6ms
# 960:	learn: 65925.3385972	total: 2.2s	remaining: 89.3ms
# 961:	learn: 65921.4293432	total: 2.2s	remaining: 87.1ms
# 962:	learn: 65916.9798549	total: 2.21s	remaining: 84.8ms
# 963:	learn: 65914.5209878	total: 2.21s	remaining: 82.5ms
# 964:	learn: 65908.3644175	total: 2.21s	remaining: 80.2ms
# 965:	learn: 65904.1480951	total: 2.21s	remaining: 77.9ms
# 966:	learn: 65898.7971901	total: 2.21s	remaining: 75.6ms
# 967:	learn: 65894.3497749	total: 2.22s	remaining: 73.3ms
# 968:	learn: 65888.1336940	total: 2.22s	remaining: 71ms
# 969:	learn: 65880.1772633	total: 2.22s	remaining: 68.7ms
# 970:	learn: 65876.1536593	total: 2.22s	remaining: 66.4ms
# 971:	learn: 65871.1427220	total: 2.23s	remaining: 64.1ms
# 972:	learn: 65868.5992824	total: 2.23s	remaining: 61.8ms
# 973:	learn: 65864.7731300	total: 2.23s	remaining: 59.5ms
# 974:	learn: 65858.2335698	total: 2.23s	remaining: 57.3ms
# 975:	learn: 65853.5960336	total: 2.24s	remaining: 55ms
# 976:	learn: 65847.5022397	total: 2.24s	remaining: 52.7ms
# 977:	learn: 65846.4643286	total: 2.24s	remaining: 50.4ms
# 978:	learn: 65844.1866330	total: 2.24s	remaining: 48.1ms
# 979:	learn: 65841.5556524	total: 2.25s	remaining: 45.8ms
# 980:	learn: 65837.0178647	total: 2.25s	remaining: 43.5ms
# 981:	learn: 65829.7942438	total: 2.25s	remaining: 41.2ms
# 982:	learn: 65826.8238224	total: 2.25s	remaining: 38.9ms
# 983:	learn: 65810.2605447	total: 2.25s	remaining: 36.7ms
# 984:	learn: 65805.4393212	total: 2.26s	remaining: 34.4ms
# 985:	learn: 65804.4836890	total: 2.26s	remaining: 32.1ms
# 986:	learn: 65795.2007126	total: 2.26s	remaining: 29.8ms
# 987:	learn: 65793.6714565	total: 2.26s	remaining: 27.5ms
# 988:	learn: 65790.4216691	total: 2.27s	remaining: 25.2ms
# 989:	learn: 65789.0870817	total: 2.27s	remaining: 22.9ms
# 990:	learn: 65784.1596949	total: 2.27s	remaining: 20.6ms
# 991:	learn: 65780.0544598	total: 2.27s	remaining: 18.3ms
# 992:	learn: 65774.6573813	total: 2.27s	remaining: 16ms
# 993:	learn: 65765.3232866	total: 2.28s	remaining: 13.7ms
# 994:	learn: 65761.4009118	total: 2.28s	remaining: 11.5ms
# 995:	learn: 65758.6691841	total: 2.28s	remaining: 9.16ms
# 996:	learn: 65754.9015955	total: 2.28s	remaining: 6.87ms
# 997:	learn: 65739.3778636	total: 2.29s	remaining: 4.58ms
# 998:	learn: 65724.5906360	total: 2.29s	remaining: 2.29ms
# 999:	learn: 65719.6800785	total: 2.29s	remaining: 0us
# 65719.6933455846
# 66680.01565894119

# %%
best_params ={
    'task_type': "GPU",
    'devices': '0',
    'learning_rate' : .175,
    'iterations' :71,
    'eval_metric' : 'RMSE',
    'depth' : 8,
    'random_seed' : 42,
    'bootstrap' : 'Bernoulli'
    }

# %%
# ?CatBoostRegressor
# Out:
# Init signature:
# CatBoostRegressor(
#     iterations=None,
#     learning_rate=None,
#     depth=None,
#     l2_leaf_reg=None,
#     model_size_reg=None,
#     rsm=None,
#     loss_function='RMSE',
#     border_count=None,
#     feature_border_type=None,
#     per_float_feature_quantization=None,
#     input_borders=None,
#     output_borders=None,
#     fold_permutation_block=None,
#     od_pval=None,
#     od_wait=None,
#     od_type=None,
#     nan_mode=None,
#     counter_calc_method=None,
#     leaf_estimation_iterations=None,
#     leaf_estimation_method=None,
#     thread_count=None,
#     random_seed=None,
#     use_best_model=None,
#     best_model_min_trees=None,
#     verbose=None,
#     silent=None,
#     logging_level=None,
#     metric_period=None,
#     ctr_leaf_count_limit=None,
#     store_all_simple_ctr=None,
#     max_ctr_complexity=None,
#     has_time=None,
#     allow_const_label=None,
#     target_border=None,
#     one_hot_max_size=None,
#     random_strength=None,
#     random_score_type=None,
#     name=None,
#     ignored_features=None,
#     train_dir=None,
#     custom_metric=None,
#     eval_metric=None,
#     bagging_temperature=None,
#     save_snapshot=None,
#     snapshot_file=None,
#     snapshot_interval=None,
#     fold_len_multiplier=None,
#     used_ram_limit=None,
#     gpu_ram_part=None,
#     pinned_memory_size=None,
#     allow_writing_files=None,
#     final_ctr_computation_mode=None,
#     approx_on_full_history=None,
#     boosting_type=None,
#     simple_ctr=None,
#     combinations_ctr=None,
#     per_feature_ctr=None,
#     ctr_description=None,
#     ctr_target_border_count=None,
#     task_type=None,
#     device_config=None,
#     devices=None,
#     bootstrap_type=None,
#     subsample=None,
#     mvs_reg=None,
#     sampling_frequency=None,
#     sampling_unit=None,
#     dev_score_calc_obj_block_size=None,
#     dev_efb_max_buckets=None,
#     sparse_features_conflict_fraction=None,
#     max_depth=None,
#     n_estimators=None,
#     num_boost_round=None,
#     num_trees=None,
#     colsample_bylevel=None,
#     random_state=None,
#     reg_lambda=None,
#     objective=None,
#     eta=None,
#     max_bin=None,
#     gpu_cat_features_storage=None,
#     data_partition=None,
#     metadata=None,
#     early_stopping_rounds=None,
#     cat_features=None,
#     grow_policy=None,
#     min_data_in_leaf=None,
#     min_child_samples=None,
#     max_leaves=None,
#     num_leaves=None,
#     score_function=None,
#     leaf_estimation_backtracking=None,
#     ctr_history_unit=None,
#     monotone_constraints=None,
#     feature_weights=None,
#     penalties_coefficient=None,
#     first_feature_use_penalties=None,
#     per_object_feature_penalties=None,
#     model_shrink_rate=None,
#     model_shrink_mode=None,
#     langevin=None,
#     diffusion_temperature=None,
#     posterior_sampling=None,
#     boost_from_average=None,
#     text_features=None,
#     tokenizers=None,
#     dictionaries=None,
#     feature_calcers=None,
#     text_processing=None,
#     embedding_features=None,
#     eval_fraction=None,
#     fixed_binary_splits=None,
# )
# Docstring:
# Implementation of the scikit-learn API for CatBoost regression.
#
# Parameters
# ----------
# Like in CatBoostClassifier, except loss_function, classes_count, class_names and class_weights
#
# loss_function : string, [default='RMSE']
#     'RMSE'
#     'MAE'
#     'Quantile:alpha=value'
#     'LogLinQuantile:alpha=value'
#     'Poisson'
#     'MAPE'
#     'Lq:q=value'
#     'SurvivalAft:dist=value;scale=value'
# Init docstring:
# Initialize the CatBoost.
#
# Parameters
# ----------
# params : dict
#     Parameters for CatBoost.
#     If  None, all params are set to their defaults.
#     If  dict, overriding parameters present in dict.
# File:           ~/anaconda3/envs/rapids-25.04/lib/python3.12/site-packages/catboost/core.py
# Type:           type
# Subclasses:

# %%
test_param_and_plot(CatBoostRegressor, 'subsample', [0.1, .3, .5, .7, .9], **best_params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 test_param_and_plot(CatBoostRegressor, 'subsample', [0.1, .3, .5, .7, .9], **best_params)
#
# Cell In[60], line 59, in test_param_and_plot(ModelClass, param_name, param_values, **other_params)
#      57 params = dict(other_params)
#      58 params[param_name] = value
# ---> 59 train_rmse, val_rmse = test_params(ModelClass, **params)
#      60 train_errors.append(train_rmse)
#      61 val_errors.append(val_rmse)
#
# Cell In[60], line 48, in test_params(ModelClass, **params)
#      47 def test_params(ModelClass, **params):
# ---> 48     model = ModelClass(**params).fit(X_train, Y_train)
#      49     train_rmse = rmse(model.predict(X_train), Y_train)
#      50     val_rmse = rmse(model.predict(X_val), Y_val)
#
# TypeError: CatBoostRegressor.__init__() got an unexpected keyword argument 'bootstrap'

# %%
66572.65 / 66442.23 / 66326.04 / 128 / 0.1
65749.63 / 65641.04 / 65603.00 / 512 / 0.05
65439.79 / 65298.49 / 65344.98 / 64 / 0.1
65353.20 / 65171.97 / 65626.14 / 64 / 0.2
65329.91 / 65045.83 / 66442.59 / 71 / 1.75

# %%
test_preds = model.predict(test)
sub['price'] = test_preds
sub.to_csv('catboost_submision.csv', index=None)
